# %%
wb<-read.csv('biomarkers_20190331.tsv',header = T, sep = "\t")

# %%
head(wb)
# Out:
#   X.GBE_ID PRS_model  phe_type features                R_or_AUC
# 1 INI30600 snpnet_PRS qt       Covariates_only         0.13494630
# 2 INI30600 snpnet_PRS qt       Genotype_and_covariates 0.14942560
# 3 INI30600 snpnet_PRS qt       Genotype_only           0.08642264
# 4 INI30620 snpnet_PRS qt       Covariates_only         0.23989670
# 5 INI30620 snpnet_PRS qt       Genotype_and_covariates 0.34083830
# 6 INI30620 snpnet_PRS qt       Genotype_only           0.25575040
#   phe_name
# 1 Albumin
# 2 Albumin
# 3 Albumin
# 4 Alanine.aminotransferase
# 5 Alanine.aminotransferase
# 6 Alanine.aminotransferase

# %%
library(ggplot2)

# %%
ggplot(wb, aes(x=phe_name, y=R_or_AUC, color=features)) + geom_point(shape=1) + theme(axis.text.x = element_text(angle = 90, hjust = 1)) + labs(x = "Phenotype", y = "R")
# Out:
# plot without title

# %%
ggplot(wb, aes(fill=features, y=R_or_AUC, x=phe_name)) + 
    geom_bar(position="dodge", stat="identity") + theme_minimal() + theme(axis.text.x = element_text(angle = 90, hjust = 1)) + labs(x = "Phenotype", y = "R") + scale_fill_brewer(palette = "Set2")
# Out:
# plot without title
